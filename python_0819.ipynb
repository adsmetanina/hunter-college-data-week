# %% [markdown]
# <a href="https://colab.research.google.com/github/adsmetanina/hunter-college-data-week/blob/main/python_0819.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/stjohn/datasci/main/openDataWeek/tickets.csv'
tickets = pd.read_csv(url)

print(tickets)

## series: one directional array (vertical information)
## index: row number
# Out:
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0        1335632335    L040HZ                 FL        PAS  06/09/2015
# 1        1351345497   GYA2946                 NY        PAS  06/25/2015
# 2        1355390564  T512895C                 NY        OMT  07/06/2015
# 3        1355390825   GVX5273                 NY        PAS  06/28/2015
# 4        1355390862     GOLPO                 NY        OMT  07/06/2015
# ..              ...       ...                ...        ...         ...
# 994      7326771054    XARL98                 NJ        PAS  07/24/2015
# 995      7326771121   HXD2344                 PA        PAS  07/24/2015
# 996      7326771182    XR351G                 NJ        PAS  07/24/2015
# 997      7326771236   GVA4260                 NY        PAS  07/24/2015
# 998      7313165900  T648267C                 NY        OMT  07/10/2015
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
s = pd.Series(["welcome", "to", "data100"])

s.index

print(s)

s = pd.Series([-1, 10, 2], index = ["a", "b", "c"])

s.index = ["first", "second", "third"]

print(s)
# Out:
# 0    welcome
# 1         to
# 2    data100
# dtype: object
# first     -1
# second    10
# third      2
# dtype: int64

# %%
s = pd.Series([4, -2, 0, 6], index = ["a", "b", "c", "d"])

s[["a", "c"]]
# Out:
# a    4
# c    0
# dtype: int64

# %%
s_a = pd.Series(["a1", "a2", "a3"], index = ["r1", "r2", "r3"])
s_b = pd.Series(["b1", "b2", "b3"], index = ["r1", "r2", "r3"])
pd.DataFrame({"A-column":s_a, "B-column":s_b})
# Out:
#    A-column B-column
# r1       a1       b1
# r2       a2       b2
# r3       a3       b3

# %%
tickets.set_index("Registration State")
# Out:
#                     Summons Number  Plate ID Plate Type  Issue Date  \
# Registration State
# FL                      1335632335    L040HZ        PAS  06/09/2015
# NY                      1351345497   GYA2946        PAS  06/25/2015
# NY                      1355390564  T512895C        OMT  07/06/2015
# NY                      1355390825   GVX5273        PAS  06/28/2015
# NY                      1355390862     GOLPO        OMT  07/06/2015
# ...                            ...       ...        ...         ...
# NJ                      7326771054    XARL98        PAS  07/24/2015
# PA                      7326771121   HXD2344        PAS  07/24/2015
# NJ                      7326771182    XR351G        PAS  07/24/2015
# NY                      7326771236   GVA4260        PAS  07/24/2015
# NY                      7313165900  T648267C        OMT  07/10/2015
#
#                     Violation Code Vehicle Body Type Vehicle Make  \
# Registration State
# ...

# %%
url = 'https://raw.githubusercontent.com/stjohn/datasci/main/openDataWeek/tickets.csv'

tickets = pd.read_csv(url, index_col = "Registration State") # select new column as index

# %%
tickets.head(5)
tickets.tail(5)
print(tickets.head)
# Out:
# <bound method NDFrame.head of                     Summons Number  Plate ID Plate Type  Issue Date  \
# Registration State
# FL                      1335632335    L040HZ        PAS  06/09/2015
# NY                      1351345497   GYA2946        PAS  06/25/2015
# NY                      1355390564  T512895C        OMT  07/06/2015
# NY                      1355390825   GVX5273        PAS  06/28/2015
# NY                      1355390862     GOLPO        OMT  07/06/2015
# ...                            ...       ...        ...         ...
# NJ                      7326771054    XARL98        PAS  07/24/2015
# PA                      7326771121   HXD2344        PAS  07/24/2015
# NJ                      7326771182    XR351G        PAS  07/24/2015
# NY                      7326771236   GVA4260        PAS  07/24/2015
# NY                      7313165900  T648267C        OMT  07/10/2015
#
#                     Violation Code Vehicle Body Type Vehicle Make  \
# Registration State
# ...

# %%
tickets = tickets.reset_index()
# select items by label
tickets.loc[[1, 2, 3], ["Summons Number", "Plate ID", "Plate Type"]]
tickets.loc[:, ["Summons Number", "Plate ID", "Plate Type"]]
# Out:
#      Summons Number  Plate ID Plate Type
# 0        1335632335    L040HZ        PAS
# 1        1351345497   GYA2946        PAS
# 2        1355390564  T512895C        OMT
# 3        1355390825   GVX5273        PAS
# 4        1355390862     GOLPO        OMT
# ..              ...       ...        ...
# 994      7326771054    XARL98        PAS
# 995      7326771121   HXD2344        PAS
# 996      7326771182    XR351G        PAS
# 997      7326771236   GVA4260        PAS
# 998      7313165900  T648267C        OMT
#
# [999 rows x 3 columns]

# %%
# select items by integer
tickets.iloc[:,0:5]
tickets.iloc[[1, 3, 5], 0:5]
# Out:
#   Registration State  Summons Number Plate ID Plate Type  Issue Date
# 1                 NY      1351345497  GYA2946        PAS  06/25/2015
# 3                 NY      1355390825  GVX5273        PAS  06/28/2015
# 5                 NJ      1361379212   ZUD99Y        PAS  06/24/2015

# %%
tickets[3:7]
# Out:
#   Registration State  Summons Number Plate ID Plate Type  Issue Date  \
# 3                 NY      1355390825  GVX5273        PAS  06/28/2015
# 4                 NY      1355390862    GOLPO        OMT  07/06/2015
# 5                 NJ      1361379212   ZUD99Y        PAS  06/24/2015
# 6                 NJ      1294715331   H22CWL        PAS  07/19/2015
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 3              20               SDN        HONDA              P         35210
# 4              19               VAN        TOYOT              P             0
# 5              40               SDN        TOYOT              X         35330
# 6              17               SDN        HONDA              P         14510
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 3  ...            RED                    0.0          1994             -
# 4  ...           BLUE                    0.0          2014             -
# ...

# %%
tickets = tickets.reset_index()
tickets[['Summons Number', 'Plate ID', 'Registration State']]
# Out:
#      Summons Number  Plate ID Registration State
# 0        1335632335    L040HZ                 FL
# 1        1351345497   GYA2946                 NY
# 2        1355390564  T512895C                 NY
# 3        1355390825   GVX5273                 NY
# 4        1355390862     GOLPO                 NY
# ..              ...       ...                ...
# 994      7326771054    XARL98                 NJ
# 995      7326771121   HXD2344                 PA
# 996      7326771182    XR351G                 NJ
# 997      7326771236   GVA4260                 NY
# 998      7313165900  T648267C                 NY
#
# [999 rows x 3 columns]

# %%
tickets["Registration State"]
# Out:
# 0      FL
# 1      NY
# 2      NY
# 3      NY
# 4      NY
#        ..
# 994    NJ
# 995    PA
# 996    NJ
# 997    NY
# 998    NY
# Name: Registration State, Length: 999, dtype: object

# %%
# much faster than .loc and .iloc
tickets["Plate ID"]
# Out:
# 0        L040HZ
# 1       GYA2946
# 2      T512895C
# 3       GVX5273
# 4         GOLPO
#          ...
# 994      XARL98
# 995     HXD2344
# 996      XR351G
# 997     GVA4260
# 998    T648267C
# Name: Plate ID, Length: 999, dtype: object

# %%
tickets.loc[[1, 2, 3], ["Summons Number", "Plate ID", "Plate Type"]]
tickets[["Summons Number", "Plate ID", "Plate Type"]][1:4]
# Out:
#    Summons Number  Plate ID Plate Type
# 1      1351345497   GYA2946        PAS
# 2      1355390564  T512895C        OMT
# 3      1355390825   GVX5273        PAS

# %%
tickets['plate_len'] = tickets['Plate ID'].str.len()

# %%
tickets["Issue Date"].value_counts()
# Out:
# Issue Date
# 06/26/2015    60
# 07/11/2015    52
# 06/29/2015    51
# 07/10/2015    50
# 07/16/2015    39
# 07/23/2015    37
# 07/15/2015    36
# 07/28/2015    34
# 06/27/2015    33
# 07/09/2015    32
# 07/24/2015    32
# 07/01/2015    31
# 07/14/2015    28
# 07/07/2015    28
# 06/30/2015    27
# 07/20/2015    26
# 07/02/2015    26
# 07/08/2015    25
# 07/17/2015    23
# 07/13/2015    23
# 07/22/2015    23
# 06/28/2015    21
# 07/27/2015    21
# 07/18/2015    20
# 07/06/2015    18
# 06/24/2015    18
# 07/19/2015    17
# 07/25/2015    16
# 06/12/2015    14
# 07/21/2015    11
# 07/26/2015    11
# 06/18/2015    11
# 07/12/2015    10
# 06/14/2015     9
# 06/19/2015     9
# 06/25/2015     7
# 06/22/2015     7
# 06/13/2015     7
# 07/05/2015     7
# 06/23/2015     7
# 06/20/2015     6
# 06/21/2015     6
# 07/04/2015     6
# 06/16/2015     4
# 06/17/2015     3
# 06/07/2015     3
# 06/15/2015     2
# 06/09/2015     1
# 06/03/2015     1
# 06/10/2015     1
# 05/04/2015     1
# ...

# %%
tickets['Vehicle Color'].value_counts()
# Out:
# Vehicle Color
# WHITE    156
# GY       112
# BK       104
# BLACK    103
# WH        91
# GREY      55
# BLUE      53
# SILVE     49
# RED       43
# BL        40
# GRAY      22
# BLK       22
# RD        22
# GREEN     15
# GR        13
# OTHER     12
# YELLO     11
# TN         9
# TAN        7
# GL         5
# GRY        5
# GOLD       4
# LTG        4
# ORANG      4
# WHT        3
# BR         3
# MR         3
# BLU        2
# BROWN      2
# BRW        1
# BIK        1
# SILV       1
# WTR        1
# SILVR      1
# B          1
# YL         1
# GN         1
# LT/        1
# DKB        1
# Name: count, dtype: int64

# %%
tickets.describe()
# Out:
#             index  Summons Number  Violation Code  Street Code1  Street Code2  \
# count  999.000000    9.990000e+02      999.000000    999.000000    999.000000
# mean   499.000000    5.193755e+09       33.481481  27266.206206  21555.118118
# std    288.530761    2.736069e+09       17.455911  11342.264132  13381.648236
# min      0.000000    1.294715e+09       10.000000      0.000000      0.000000
# 25%    249.500000    1.384288e+09       20.000000  14510.000000  13610.000000
# 50%    499.000000    7.039109e+09       37.000000  35170.000000  15710.000000
# 75%    748.500000    7.281398e+09       40.000000  35350.000000  35290.000000
# max    998.000000    7.326771e+09       99.000000  44990.000000  97560.000000
#
#        Street Code3  Vehicle Expiration Date  Violation Location  \
# count    999.000000             9.990000e+02               999.0
# mean   22638.039039             2.670042e+07                20.0
# std    13831.658959             2.692534e+07                 0.0
# ...

# %%
tickets["Feet From Curb"].describe()
# Out:
# count    999.000000
# mean       0.262262
# std        1.273000
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       10.000000
# Name: Feet From Curb, dtype: float64
